# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# Creation of data
np.random.seed(42)
X = np.random.rand(100, 1) * 4 - 2
# Noise is directly proportional to number multplied
y = 4 + 2 * X + 5 * X**2 + np.random.rand(100, 1) * 4

# %%
# %matplotlib inline
plt.scatter(X, y, color='red', marker='+')

# %%
reg = LinearRegression()
reg.fit(X.reshape(-1, 1), y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 reg = linear_model.LinearRegression()
#       2 reg.fit(X.reshape(-1, 1), y)
#
# NameError: name 'linear_model' is not defined

# %%
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_vals = np.linspace(-2, 2, 100).reshape(-1 ,1)
X_vals_poly = poly_features.transform(X_vals)

y_vals = model.predict(X_vals_poly)

# %%
# %matplotlib inline
plt.scatter(X, y, color='r', marker='+')
plt.plot(X_vals, y_vals, color='black')
